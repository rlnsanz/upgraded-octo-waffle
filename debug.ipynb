# %%
import flor

# %%
kvs = flor.load_kvs()

# %%
# !python -m flor unpack
# Out:
# copied 6decbe2e6aa7a28cf1b718e9f8b8724db40943ab::2022-10-09T13:14:39.json
# copied d7f5eeed92efaae9b61e710865e657c61638758e::2022-10-08T06:20:52.json
# copied 4b3f3d4c2d72859554e5540cd475278626fd84a7::2022-10-06T21:37:19.json
# copied 1f1fe092b6725e0ddbfc5a23591f601dbed1f29d::2022-10-06T19:27:23.json

# %%
# !git log
# Out:
# commit 722fe07b9bd52c9c66c36d680cf1a19fc217cdc1 (HEAD -> flor.shadow, origin/flor.shadow)
# Author: Rolando Garcia <rogarcia@berkeley.edu>
# Date:   Thu Oct 20 05:37:49 2022 -0700
#
#     .
#
# commit 6decbe2e6aa7a28cf1b718e9f8b8724db40943ab
# Author: Rolando Garcia <rogarcia@berkeley.edu>
# Date:   Sun Oct 9 13:18:32 2022 -0700
#
#     flor.shadow@squeeze-floret::2022-10-09T13:14:39.json
#
# commit af0592277dc049c32b3c2437f7ede3a635ad2a12
# Merge: 0293e90 d7f5eee
# Author: Rolando Garcia <rlnsanz@users.noreply.github.com>
# Date:   Sun Oct 9 13:05:13 2022 -0700
#
#     Merge pull request #1 from rlnsanz/flor.shadow
#
#     Flor.shadow
#
# commit d7f5eeed92efaae9b61e710865e657c61638758e
# Author: rogarcia <rogarcia@SEGUNDO>
# Date:   Sat Oct 8 06:57:56 2022 -0700
#
#     flor.shadow@wsl_squeeze::2022-10-08T06:20:52.json
#
# commit 4b3f3d4c2d72859554e5540cd475278626fd84a7
# Author: Rolando Garcia <rogarcia@berkeley.edu>
# Date:   Thu Oct 6 22:25:05 2022 -0700
#
# ...

# %%
kvs
# Out:
# Empty DataFrame
# Columns: [projid, vid, tstamp, alpha, epoch, step, name, value]
# Index: []
